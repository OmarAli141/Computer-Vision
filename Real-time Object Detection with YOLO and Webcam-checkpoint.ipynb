# %%
pip install ultralytics
# Out:
# Collecting ultralyticsNote: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.4 which is incompatible.
#   Downloading ultralytics-8.2.74-py3-none-any.whl (865 kB)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting ultralytics-thop>=2.0.0
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Collecting numpy<2.0.0,>=1.23.0
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Collecting torchvision>=0.9.0
#   Downloading torchvision-0.19.0-1-cp39-cp39-win_amd64.whl (1.3 MB)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\anaconda\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: torch>=1.8.0 in d:\anaconda\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: pandas>=1.1.4 in d:\anaconda\lib\site-packages (from ultralytics) (1.4.2)
# Requirement already satisfied: scipy>=1.4.1 in d:\anaconda\lib\site-packages (from ultralytics) (1.7.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\anaconda\lib\site-packages (from ultralytics) (0.11.2)
# Requirement already satisfied: requests>=2.23.0 in d:\anaconda\lib\site-packages (from ultralytics) (2.27.1)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\anaconda\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\anaconda\lib\site-packages (from ultralytics) (3.5.1)
# Requirement already satisfied: pillow>=7.1.2 in d:\anaconda\lib\site-packages (from ultralytics) (9.0.1)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from ultralytics) (5.8.0)
# Requirement already satisfied: tqdm>=4.64.0 in d:\anaconda\lib\site-packages (from ultralytics) (4.64.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=1.1.4->ultralytics) (2021.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3)
# Collecting scipy>=1.4.1
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from torch>=1.8.0->ultralytics) (4.1.1)
# Collecting torch>=1.8.0
#   Downloading torch-2.4.0-cp39-cp39-win_amd64.whl (198.0 MB)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch>=1.8.0->ultralytics) (2.11.3)
# Requirement already satisfied: networkx in d:\anaconda\lib\site-packages (from torch>=1.8.0->ultralytics) (2.7.1)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: fsspec in d:\anaconda\lib\site-packages (from torch>=1.8.0->ultralytics) (2022.2.0)
# Requirement already satisfied: sympy in d:\anaconda\lib\site-packages (from torch>=1.8.0->ultralytics) (1.10.1)
# Collecting typing-extensions
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.2.1)
# Installing collected packages: typing-extensions, numpy, torch, scipy, ultralytics-thop, torchvision, py-cpuinfo, ultralytics
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed numpy-1.26.4 py-cpuinfo-9.0.0 scipy-1.13.1 torch-2.4.0 torchvision-0.19.0 typing-extensions-4.12.2 ultralytics-8.2.74 ultralytics-thop-2.0.0

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolo-Weights\yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:01<00:00, 3.72MB/s]

# %%
# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

# %%
import cv2
import math

# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 891.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 174.7ms preprocess, 891.3ms inference, 69.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 265.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 15.5ms preprocess, 265.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 112.0ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 107.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 114.1ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 107.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.5ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.4ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 97.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 96.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 111.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.1ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.3ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.0ms preprocess, 124.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 109.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 111.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.6ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.0ms preprocess, 108.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.2ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.6ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.5ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 103.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 120.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.2ms preprocess, 112.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 90.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.3ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 0.0ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 104.9ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.56
# Class name --> remote
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.9ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.2ms
# Confidence ---> 0.61
# Class name --> person
# Speed: 0.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 111.2ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 0.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 111.1ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.0ms preprocess, 111.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 98.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 0.0ms preprocess, 98.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 109.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 95.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 remote, 97.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.41
# Class name --> remote
# Speed: 0.0ms preprocess, 97.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 98.7ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 112.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 118.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 110.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.1ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.6ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.2ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 2.1ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 118.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.35
# Class name --> cat
# Speed: 0.0ms preprocess, 118.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 101.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 94.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 4.8ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 103.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 107.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.0ms preprocess, 107.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.1ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 95.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 0.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 99.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.9ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 111.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 98.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.9ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 0.0ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.8ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 92.0ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> person
# Speed: 0.0ms preprocess, 92.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 99.8ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.66
# Class name --> cell phone
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 105.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 0.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 105.9ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
# Speed: 0.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 107.7ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 107.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 98.7ms
# Confidence ---> 0.86
# Class name --> cell phone
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.0ms preprocess, 98.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 104.8ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 91.2ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 91.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 96.1ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 103.3ms
# Confidence ---> 0.82
# Class name --> cell phone
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 105.5ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 105.0ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 91.6ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.4
# Class name --> cell phone
# Speed: 0.0ms preprocess, 91.6ms inference, 16.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 103.2ms
# Confidence ---> 0.86
# Class name --> cell phone
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.0ms preprocess, 103.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 103.1ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.66
# Class name --> cell phone
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 102.9ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.0ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 101.9ms
# Confidence ---> 0.88
# Class name --> cell phone
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.0ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 103.5ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> cell phone
# Confidence ---> 0.39
# Class name --> person
# Speed: 0.0ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 103.8ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
# Confidence ---> 0.48
# Class name --> person
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 101.8ms
# Confidence ---> 0.85
# Class name --> cell phone
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 0.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 104.9ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 106.2ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.57
# Class name --> cell phone
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 103.5ms
# Confidence ---> 0.84
# Class name --> cell phone
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.0ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 105.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.38
# Class name --> cell phone
# Speed: 0.0ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 101.4ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 101.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.2ms preprocess, 132.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 126.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 123.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 108.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 104.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 100.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.44
# Class name --> toothbrush
# Speed: 0.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.6ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 0.0ms preprocess, 98.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 113.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.9ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.0ms preprocess, 90.9ms inference, 17.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.7ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 104.9ms
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.37
# Class name --> donut
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 104.5ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.32
# Class name --> donut
# Speed: 0.0ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.6ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 0.0ms preprocess, 103.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 108.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.41
# Class name --> donut
# Speed: 0.0ms preprocess, 108.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.3ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.3ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 97.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.9ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 4.7ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.5ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 88.5ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 100.2ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 103.6ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 0.0ms preprocess, 103.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.9ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.0ms preprocess, 122.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.7ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.0ms preprocess, 113.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.9ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 0.0ms preprocess, 114.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 94.8ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.42
# Class name --> donut
# Speed: 0.0ms preprocess, 94.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 97.5ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.39
# Class name --> donut
# Speed: 0.0ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 88.6ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 0.0ms preprocess, 88.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.9ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 0.0ms preprocess, 97.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 106.0ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.27
# Class name --> donut
# Speed: 0.0ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.5ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 0.0ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.5ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 0.0ms preprocess, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 89.5ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.26
# Class name --> donut
# Speed: 0.0ms preprocess, 89.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.0ms
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.1ms preprocess, 92.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.7ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 0.0ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.4ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 0.0ms preprocess, 91.4ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.3ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 0.0ms preprocess, 97.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.9ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 0.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.3ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 0.0ms preprocess, 89.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 100.0ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.3
# Class name --> donut
# Speed: 4.1ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.2ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 frisbee, 1 toothbrush, 107.3ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.47
# Class name --> toothbrush
# Confidence ---> 0.26
# Class name --> frisbee
# Speed: 0.0ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.9ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 93.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.9ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 120.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.5ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 135.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.0ms preprocess, 119.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 106.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 111.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.27
# Class name --> tie
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 105.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 106.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 vase, 97.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.47
# Class name --> vase
# Speed: 3.0ms preprocess, 97.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 5.1ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 105.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.8ms preprocess, 104.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 106.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.9ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 113.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.3ms preprocess, 113.7ms inference, 16.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 167.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 136.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 128.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 121.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 119.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 103.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 108.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 108.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 94.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 104.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 91.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 105.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 98.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 93.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 89.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 7.6ms preprocess, 89.3ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 106.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 90.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.6ms preprocess, 90.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 120.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 118.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 106.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.1ms preprocess, 92.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 85.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.0ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.8ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.6ms preprocess, 92.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 103.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 1.0ms preprocess, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 141.9ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.1ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 92.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.1ms preprocess, 92.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.1ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 95.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 93.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 83.3ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 1.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 94.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 95.7ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.0ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 95.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.0ms
# Confidence ---> 0.87
# Class name --> person
# ...
#
# 0: 480x640 1 person, 96.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 113.0ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 97.3ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 106.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 95.5ms inference, 17.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 2.5ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 94.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.1ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.1ms preprocess, 108.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 96.7ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.0ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 93.1ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 197.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 112.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 111.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 106.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 108.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 110.0ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 123.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.6ms preprocess, 137.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 106.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 97.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.1ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 114.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 114.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 120.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 91.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 108.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 93.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 101.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 127.4ms inference, 15.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.4ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 96.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 103.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 98.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 128.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 123.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.5ms preprocess, 125.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 106.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.2ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 104.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 124.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.8ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.5ms preprocess, 96.8ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 127.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.7ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 95.7ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 93.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.1ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 106.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.6ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 99.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 94.6ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 111.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 97.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 97.3ms inference, 17.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 100.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 100.3ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 94.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 94.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 97.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.3ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 96.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 96.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 144.1ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 96.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
